# %%
import pandas as pd

# %%
mr=pd.read_csv(r"D:\nit_prac\assignments\Movie-Rating.csv")

# %%
import numpy
print(numpy. __version__)
# Out:
# 1.26.4

# %%
import pandas
print(pandas. __version__)
# Out:
# 2.2.2

# %%
mr.shape
# Out:
# (559, 6)

# %%
mr.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
mr.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
mr.info
# Out:
# <bound method DataFrame.info of                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# ...

# %%
mr.columns  

#we need to rename as they are confusing
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
mr.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
mr.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
mr.head(2)
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008

# %%
mr.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
mr.Film=mr.Film.astype('category')

# %%
mr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
mr.Genre = mr.Genre.astype('category')

# %%
mr.Year = mr.Year.astype('category')

# %%
mr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
mr.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=mr,x='CriticRating', y='AudienceRating', kind='hex')

# %% [raw]
# A joint plot in Seaborn (a data visualization library based on Matplotlib) is a type of plot that allows you to visualize the relationship between two variables, along with their individual distributions.
#
# Draw a plot of two variables with bivariate and univariate graphs.
#
# - sns.jointplot is a Seaborn function that creates a combined plot:
# - A scatter plot (by default) in the center showing the relationship between CriticRating and AudienceRating.
# - A histogram or KDE [Kernel Density Estimation] plot of CriticRating on the top.
# - A histogram or KDE plot of AudienceRating on the right.
# - data=mr: uses the DataFrame mr as the source of the data.
# - x='CriticRating' and y='AudienceRating': specify the columns in the DataFrame to plot.

# %% [raw]
# - audience rating is more dominant than critics rating <=== from graph
# - positive correlation
# -kde hex hist reg resid

# %%
m1=sns.distplot(mr.AudienceRating)

# %%
m1=sns.distplot(mr.CriticRating)

# %%
m1=sns.displot(mr.CriticRating)

# %%
sns.set_style('darkgrid')

# %% [raw]
# - style = darkgrid, whitegrid, dark, white, ticks

# %%
sns.set_style('white')

# %%
m1=sns.displot(mr.CriticRating)

# %%
plt.hist(mr.BudgetMillions)
plt.show()

# %%
vis2=sns.lmplot(data=mr,x='CriticRating', y='AudienceRating',fit_reg=True)

# %%
vis2=sns.lmplot(data=mr,x='CriticRating', y='AudienceRating',fit_reg=False)

# %%
vis2=sns.lmplot(data=mr,x='CriticRating', y='AudienceRating',\
                fit_reg=False, hue='Genre') 

# hue is just like legend in numpy

# %%
#subplots ---> when u want to show more graphs at a time
ax=plt.subplots(1,2, figsize = (3,3))
#ax=plt.subplots(3,3, figsize=(10,8))

# %%
#box plot
w=sns.boxplot(data=mr,x='Genre',y='CriticRating')

# %%
# diff. with box plot --> is avg. lines are different in violin plot
w=sns.violinplot(data=mr,x='Genre',y='CriticRating')

# %%
#if u want to analyse one particular 
vis3=sns.boxplot(data=mr[mr.Genre=='Drama'], x='Year',y='AudienceRating')

# %% [raw]
# univariate--> plot using 1 var
# bivariate--> 2 var like scatter plot
# multivariate--> dataset--20 attribute (heatmap , pairplot, facetgrid)

# %%
g= sns.FacetGrid(mr, row='Genre', col='Year', hue='Genre')

# %%
g=g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
g= sns.FacetGrid(mr, row='Genre', col='Year', hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')

# %% [raw]
# using this both we understand which movie was liked my the audience and suggest the producer

# %%
obj_data = ( ) 
type(obj_data)
# Out:
# tuple
